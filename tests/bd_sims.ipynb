# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pylab as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import brown as bd

# %%
nParticles=100
nUpdates = 1000
#ts,xs,ys = bd.runBD(display=True,nParticles=nParticles,nUpdates=nUpdates,addForce=False) #True)
ts,xs,ys = bd.runBD(display=True,nParticles=nParticles,nUpdates=nUpdates,addForce=True)
# Out:
# Adding force

# %%
for i in range(nParticles):
  plt.plot(xs[i,:],ys[i,:])

for i in range(nParticles):
  plt.scatter(xs[i,-1],ys[i,-1])
#plt.xlim([-1,2])
#plt.ylim([0,2])

# %%
x0s = xs[:,0]
y0s = ys[:,1]
msds = np.zeros(nUpdates)
for i in range(nUpdates):
  #j = 0
  #xmsd = xs[j,i] - x0s[j]
  #ymsd = ys[j,i] - y0s[j]
  xmsd = xs[:,i] - x0s
  ymsd = ys[:,i] - y0s

  sd = xmsd*xmsd + ymsd*ymsd
  msd = np.mean(sd)
  msds[i] = msd

# %%
plt.plot(msds)
